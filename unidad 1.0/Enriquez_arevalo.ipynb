# %% [markdown]
# <a href="https://colab.research.google.com/github/DavidEA-26/probabilidadyestadistica/blob/main/unidad%201.0/Enriquez_arevalo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
#
#
#
#
#
#
# ## Probabilidad y estadistica
#
# # unidad 1
#
# # Practica 1. estadistica de los Histogramas
#
# # facilitador: DR Jose Gabriel Rodriguez Rivas
#
# # Alumno: Luis David Enriquez Arevalo

# %%
from statistics import *
# lista de calificaciones del grupo a probabilidad y estsadistica
grupoa = [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
print("el promedio del grupo es =>", mean(grupoa))
mediana = median(grupoa)
print("la mediana del grupo es =>", mediana)
moda = mode("grupoa")
print("la moda del grupo es =>", moda)
#cuando hay mas de una moda se pone multimodas en lugar de moda
[70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]

moda2  = multimode(grupoa)
print(moda2)
# Out:
# el promedio del grupo es => 75.33333333333333
# la mediana del grupo es => 76.5
# la moda del grupo es => g
# [70, 100]

# %%
from statistics import *
tiempos100mts = [15.10, 17.20, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.10, 17.20]

print(tiempos100mts)
print("el tiempo promedio de los corredores es =>", mean(tiempos100mts))
mediana = median(tiempos100mts)
print("la mediana de los tiempos de los corredores  es =>", mediana)
moda = mode (tiempos100mts)
print("la moda de los tiemmpos es=>", moda )

# %%
import random
fabrica1 = []
for i in range(100):
    numero_aleatorio = round( random.uniform(50, 100), 2)
    fabrica1.append(numero_aleatorio)
print(fabrica1)

import matplotlib.pyplot as plt
plt.hist(fabrica1)
plt.title("produccion diaria de la fabrica 1")
media1 = mean(fabrica1)
mediana1 = median (fabrica1)
moda1 = mode (fabrica1)
print("la media de la fabrica 1 es =>", media1)
print("la mediana de la fabrica 1 es =>", mediana1)
print("la moda de la fabrica 1 es =>", moda1)







import random
fabrica2 = []
for i in range(100):
    numero_aleatorio = round( random.uniform(50, 100), 2)
    fabrica2.append(numero_aleatorio)
print(fabrica2)

import matplotlib.pyplot as plt
plt.hist(fabrica2)
plt.title("produccion diaria de la fabrica 2")
media2 = mean(fabrica2)
mediana2 = median (fabrica2)
moda2 = mode (fabrica2)
print("la media de la fabrica 2 es =>", media2)
print("la mediana de la fabrica 2 es =>", mediana2)
print("la moda de la fabrica 2 es =>", moda2)

fig, (ax1, ax2) = plt.subplots(nrows =1, ncols=2, figsize=(10,5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()

plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label='media')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label='mediana')
plt.axvline(moda1, color='y', linestyle = 'dashed', linewidth=2, label= 'moda')
plt.xlabel('valor')
plt.ylabel('Frecuencia')
plt.title("Produccion diaria de la fabrica 1")
plt.legend()
plt,show()

plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label='media')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label='mediana')
plt.axvline(moda2, color='y', linestyle = 'dashed', linewidth=2, label= 'moda')
plt.xlabel('valor')
plt.ylabel('Frecuencia')
plt.title("Produccion diaria de la fabrica 1")
plt.legend()
plt,show()
# Out:
# [64.38, 88.7, 72.43, 80.19, 73.76, 70.19, 54.62, 83.55, 70.54, 65.92, 93.99, 95.88, 63.97, 83.93, 56.92, 88.49, 71.03, 82.14, 89.51, 68.51, 93.27, 69.17, 56.57, 94.61, 76.8, 83.58, 84.1, 75.74, 78.31, 61.55, 80.27, 55.62, 61.18, 69.73, 74.81, 53.92, 70.8, 99.8, 76.81, 92.02, 50.14, 76.77, 81.3, 58.02, 79.71, 81.76, 83.62, 98.15, 78.72, 75.55, 80.44, 64.9, 54.4, 77.86, 70.79, 58.08, 68.02, 86.84, 84.05, 69.56, 83.29, 90.09, 91.56, 91.31, 86.61, 50.76, 58.82, 56.91, 75.16, 52.4, 92.83, 66.1, 88.25, 96.22, 86.18, 78.18, 73.25, 53.27, 57.65, 91.54, 80.86, 60.61, 80.57, 78.06, 55.29, 64.86, 71.73, 82.14, 83.2, 57.85, 97.53, 67.65, 82.41, 77.39, 86.28, 63.42, 96.82, 60.87, 72.72, 53.94]
# la media de la fabrica 1 es => 75.0057
# la mediana de la fabrica 1 es => 76.785
# la moda de la fabrica 1 es => 82.14
# [98.72, 61.78, 58.72, 62.37, 82.65, 76.85, 50.47, 98.25, 59.68, 99.11, 55.17, 94.24, 90.07, 70.01, 90.95, 54.25, 55.02, 54.54, 50.29, 82.13, 70.22, 83.5, 69.33, 88.41, 83.44, 76.9, 66.24, 71.57, 90.27, 68.54, 89.02, 67.41, 82.61, 66.47, 96.44, 55.66, 67.56, 92.78, 69.37, 98.33, 97.52, 94.3, 50.67, 92.13, 56.04, 96.62, 99.33, 99.73, 69.99, 70.89, 80.33, 55.62, 56.82, 74.84, 98.8, 63.23, 94.51, 54.8, 96.03, 65.0, 93.57, 82.07, 86.49, 97.11, 59.66, 89.8, 72.94, 59.42, 73.71, 87.5, 69.3, 92.02, 68.32, 95.87, 83.33, 66.63, 50.53, 86.24, 62.69, 76.69, 78.99, 84.65, 53.64, 65.85, 95.18, 52.96, 70.04, 99.46, 56.32, 54.12, 54.52, 98.78, 97.58, 81.63, 84.84, 96.62, 69.9, 58.44, 58.27, 58.37]
# la media de la fabrica 2 es => 75.9059
# la mediana de la fabrica 2 es => 74.275
# la moda de la fabrica 2 es => 96.62
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-4eed1138a39b> in <cell line: 0>()
#      52 plt.title("Produccion diaria de la fabrica 1")
#      53 plt.legend()
# ---> 54 plt,show()
#      55
#      56 plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor = "black")
#
# NameError: name 'show' is not defined
