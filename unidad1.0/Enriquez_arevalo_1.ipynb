# %% [markdown]
# <a href="https://colab.research.google.com/github/DavidEA-26/probabilidadyestadistica/blob/main/unidad1.0/Enriquez_arevalo_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
#
#
#
#
#
#
# ## Probabilidad y estadistica
#
# # unidad 1
#
# # Practica 1. estadistica de los Histogramas
#
# # facilitador: DR Jose Gabriel Rodriguez Rivas
#
# # Alumno: Luis David Enriquez Arevalo

# %%
from statistics import *
# lista de calificaciones del grupo a probabilidad y estsadistica
grupoa = [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
print("el promedio del grupo es =>", mean(grupoa))
mediana = median(grupoa)
print("la mediana del grupo es =>", mediana)
moda = mode("grupoa")
print("la moda del grupo es =>", moda)
#cuando hay mas de una moda se pone multimodas en lugar de moda
[70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]

moda2  = multimode(grupoa)
print(moda2)
# Out:
# el promedio del grupo es => 75.33333333333333
# la mediana del grupo es => 76.5
# la moda del grupo es => g
# [70, 100]

# %%
from statistics import *
tiempos100mts = [15.10, 17.20, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.10, 17.20]

print(tiempos100mts)
print("el tiempo promedio de los corredores es =>", mean(tiempos100mts))
mediana = median(tiempos100mts)
print("la mediana de los tiempos de los corredores  es =>", mediana)
moda = mode (tiempos100mts)
print("la moda de los tiemmpos es=>", moda )

# %%
import random
fabrica1 = []
for i in range(100):
    numero_aleatorio = round( random.uniform(50, 100), 2)
    fabrica1.append(numero_aleatorio)
print(fabrica1)

import matplotlib.pyplot as plt
plt.hist(fabrica1)
plt.title("produccion diaria de la fabrica 1")
media1 = mean(fabrica1)
mediana1 = median (fabrica1)
moda1 = mode (fabrica1)
print("la media de la fabrica 1 es =>", media1)
print("la mediana de la fabrica 1 es =>", mediana1)
print("la moda de la fabrica 1 es =>", moda1)







import random
fabrica2 = []
for i in range(100):
    numero_aleatorio = round( random.uniform(50, 100), 2)
    fabrica2.append(numero_aleatorio)
print(fabrica2)

import matplotlib.pyplot as plt
plt.hist(fabrica2)
plt.title("produccion diaria de la fabrica 2")
media2 = mean(fabrica2)
mediana2 = median (fabrica2)
moda2 = mode (fabrica2)
print("la media de la fabrica 2 es =>", media2)
print("la mediana de la fabrica 2 es =>", mediana2)
print("la moda de la fabrica 2 es =>", moda2)

fig, (ax1, ax2) = plt.subplots(nrows =1, ncols=2, figsize=(10,5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()

plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label='media')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label='mediana')
plt.axvline(moda1, color='y', linestyle = 'dashed', linewidth=2, label= 'moda')
plt.xlabel('valor')
plt.ylabel('Frecuencia')
plt.title("Produccion diaria de la fabrica 1")
plt.legend()
plt.show()

plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label='media')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label='mediana')
plt.axvline(moda2, color='y', linestyle = 'dashed', linewidth=2, label= 'moda')
plt.xlabel('valor')
plt.ylabel('Frecuencia')
plt.title("Produccion diaria de la fabrica 1")
plt.legend()
plt.show()
# Out:
# [69.7, 92.43, 80.96, 78.13, 96.21, 96.77, 73.36, 92.21, 92.76, 77.24, 78.47, 77.54, 52.49, 90.05, 89.53, 71.8, 99.13, 85.59, 77.38, 64.06, 78.31, 83.37, 95.81, 65.49, 70.53, 54.46, 94.4, 94.57, 92.39, 56.27, 59.32, 53.22, 81.27, 75.17, 73.48, 70.17, 57.94, 79.89, 75.58, 57.69, 87.28, 84.47, 92.76, 54.6, 59.29, 51.25, 61.84, 70.17, 90.61, 74.09, 87.54, 96.86, 83.09, 57.4, 85.21, 92.0, 61.59, 79.99, 85.71, 92.28, 89.35, 75.44, 81.2, 51.4, 89.06, 92.48, 88.04, 52.49, 50.62, 58.97, 99.14, 84.91, 58.13, 94.54, 65.66, 80.56, 73.43, 75.93, 69.25, 84.45, 95.33, 50.83, 57.26, 88.53, 63.77, 80.52, 53.19, 75.9, 64.93, 94.35, 50.2, 62.66, 84.02, 90.32, 88.74, 64.9, 93.08, 54.5, 52.74, 93.62]
# la media de la fabrica 1 es => 76.2761
# la mediana de la fabrica 1 es => 78.22
# la moda de la fabrica 1 es => 92.76
# [75.24, 92.91, 50.92, 72.33, 85.34, 88.59, 84.86, 54.7, 95.4, 50.66, 93.48, 98.07, 93.55, 56.42, 83.66, 72.64, 69.92, 70.62, 76.65, 79.67, 90.73, 79.4, 66.94, 65.58, 70.62, 88.66, 50.52, 98.63, 94.21, 82.35, 72.25, 70.43, 64.71, 89.56, 98.23, 51.79, 57.78, 51.43, 60.74, 55.5, 97.94, 78.3, 99.41, 71.98, 82.22, 58.22, 64.99, 91.65, 53.06, 83.81, 72.58, 66.76, 54.94, 94.46, 58.63, 57.41, 90.24, 53.56, 84.78, 61.17, 77.33, 66.46, 81.3, 57.3, 98.4, 100.0, 50.24, 88.45, 83.75, 75.9, 99.32, 86.83, 60.12, 87.8, 87.34, 96.31, 70.0, 54.24, 62.15, 69.3, 97.41, 51.82, 83.03, 85.23, 70.77, 77.23, 89.25, 59.49, 78.64, 52.37, 85.66, 61.74, 90.47, 53.03, 92.43, 87.15, 79.47, 71.48, 51.25, 58.82]
# la media de la fabrica 2 es => 75.1108
# la mediana de la fabrica 2 es => 76.275
# la moda de la fabrica 2 es => 70.62
