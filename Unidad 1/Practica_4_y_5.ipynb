# %% [markdown]
# <a href="https://colab.research.google.com/github/DavidEA-26/probabilidadyestadistica/blob/main/Unidad%201/Practica_4_y_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ## unidad 1
# # practica 4
#
# # Facilitador:DR Jose Gabriel Rodriguez Rivas
#
#
# # Alumno:Luis David Enriquez Arevalo

# %%
import random
edades = []
for i in range (100):
    numero_aleatorio = random.randint(18,70)
    edades.append(numero_aleatorio)
print(edades)
# Out:
# [19, 67, 29, 62, 30, 46, 48, 31, 54, 59, 55, 53, 42, 40, 35, 46, 26, 27, 55, 54, 45, 33, 41, 64, 38, 44, 61, 34, 36, 51, 54, 35, 21, 34, 49, 32, 18, 62, 22, 61, 44, 50, 36, 43, 57, 56, 44, 55, 67, 26, 66, 27, 55, 23, 69, 70, 65, 47, 46, 52, 34, 56, 22, 58, 65, 36, 25, 53, 69, 36, 68, 32, 53, 34, 70, 33, 47, 64, 22, 62, 64, 54, 45, 60, 26, 55, 27, 65, 53, 26, 54, 46, 35, 38, 19, 68, 56, 69, 59, 52]

# %%
import pandas as pd

# %%
df = pd.DataFrame(edades, columns=['edades'])
df.head()
# Out:
#    edades
# 0      19
# 1      67
# 2      29
# 3      62
# 4      30

# %%
tabla_frecuencias = df['edades'].value_counts().reset_index() # Change 'edad' to 'edades' to match the DataFrame column name
tabla_frecuencias.columns = ['edad', 'frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='edad') # 'tabla_frecuencia' was misspelled, corrected to 'tabla_frecuencias'

print("tabla de distribucion de frecuencias:")
tabla_frecuencias
# Out:
# tabla de distribucion de frecuencias:
#     edad  frecuencia
# 42    18           1
# 22    19           2
# 44    21           1
# 9     22           3
# 28    23           1
# 30    25           1
# 6     26           4
# 10    27           3
# 29    29           1
# 32    30           1
# 34    31           1
# 19    32           2
# 25    33           2
# 3     34           4
# 11    35           3
# 4     36           4
# 24    38           2
# 36    40           1
# 38    41           1
# 35    42           1
# 40    43           1
# 12    44           3
# 26    45           2
# 5     46           4
# 18    47           2
# 33    48           1
# 43    49           1
# 41    50           1
# 45    51           1
# 20    52           2
# 2     53           4
# 0     54           5
# 1     55           5
# 7     56           3
# 39    57           1
# 31    58           1
# 27    59           2
# 46    60           1
# 23    61           2
# 15    62           3
# 8     64           3
# 14    65           3
# 37    66           1
# 16    67           2
# 21    68           2
# 13    69           3
# 17    70           2

# %%
tabla_frecuencias['Frec relativa'] = tabla_frecuencias['frecuencia'] / 100
tabla_frecuencias
# Out:
#     edad  frecuencia  Frec relativa
# 7     19           3           0.03
# 37    20           1           0.01
# 39    21           1           0.01
# 10    22           3           0.03
# 6     23           3           0.03
# 45    24           1           0.01
# 9     25           3           0.03
# 19    26           2           0.02
# 32    27           2           0.02
# 12    28           2           0.02
# 17    30           2           0.02
# 1     31           4           0.04
# 26    32           2           0.02
# 25    33           2           0.02
# 48    34           1           0.01
# 33    35           1           0.01
# 34    36           1           0.01
# 47    37           1           0.01
# 0     38           5           0.05
# 5     39           3           0.03
# 40    40           1           0.01
# 2     41           4           0.04
# 30    43           2           0.02
# 24    44           2           0.02
# 41    45           1           0.01
# 35    46           1           0.01
# 20    47           2           0.02
# 28    48           2           0.02
# 27    49           2           0.02
# 18    50           2           0.02
# 22    51           2           0.02
# 44    52           1           0.01
# 23    53           2           0.02
# 16    54           2           0.02
# 8     55           3           0.03
# 36    56           1           0.01
# 14    57           2           0.02
# 46    59           1           0.01
# 29    60           2           0.02
# 11    61           3           0.03
# 15    62           2           0.02
# 3     63           4           0.04
# 38    64           1           0.01
# 31    65           2           0.02
# 43    66           1           0.01
# 13    67           2           0.02
# 42    68           1           0.01
# 21    69           2           0.02
# 4     70           4           0.04

# %%
tabla_frecuencias['Frec porcentual'] = tabla_frecuencias['frecuencia'] / 100 * 100
tabla_frecuencias
# Out:
#     edad  frecuencia  Frec porcentual
# 42    18           1              1.0
# 22    19           2              2.0
# 44    21           1              1.0
# 9     22           3              3.0
# 28    23           1              1.0
# 30    25           1              1.0
# 6     26           4              4.0
# 10    27           3              3.0
# 29    29           1              1.0
# 32    30           1              1.0
# 34    31           1              1.0
# 19    32           2              2.0
# 25    33           2              2.0
# 3     34           4              4.0
# 11    35           3              3.0
# 4     36           4              4.0
# 24    38           2              2.0
# 36    40           1              1.0
# 38    41           1              1.0
# 35    42           1              1.0
# 40    43           1              1.0
# 12    44           3              3.0
# 26    45           2              2.0
# 5     46           4              4.0
# 18    47           2              2.0
# 33    48           1              1.0
# 43    49           1              1.0
# 41    50           1              1.0
# 45    51           1              1.0
# 20    52           2              2.0
# 2     53           4              4.0
# 0     54           5              5.0
# 1     55           5              5.0
# 7     56           3              3.0
# 39    57           1              1.0
# 31    58           1              1.0
# 27    59           2              2.0
# 46    60           1              1.0
# 23    61           2              2.0
# 15    62           3              3.0
# 8     64           3              3.0
# 14    65           3              3.0
# 37    66           1              1.0
# 16    67           2              2.0
# 21    68           2              2.0
# 13    69           3              3.0
# 17    70           2              2.0

# %%
tabla_frecuencias['Frec acumulada'] = tabla_frecuencias['frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     edad  frecuencia  Frec porcentual  Frec acumulada
# 42    18           1              1.0               1
# 22    19           2              2.0               3
# 44    21           1              1.0               4
# 9     22           3              3.0               7
# 28    23           1              1.0               8
# 30    25           1              1.0               9
# 6     26           4              4.0              13
# 10    27           3              3.0              16
# 29    29           1              1.0              17
# 32    30           1              1.0              18
# 34    31           1              1.0              19
# 19    32           2              2.0              21
# 25    33           2              2.0              23
# 3     34           4              4.0              27
# 11    35           3              3.0              30
# 4     36           4              4.0              34
# 24    38           2              2.0              36
# 36    40           1              1.0              37
# 38    41           1              1.0              38
# 35    42           1              1.0              39
# 40    43           1              1.0              40
# 12    44           3              3.0              43
# 26    45           2              2.0              45
# 5     46           4              4.0              49
# 18    47           2              2.0              51
# 33    48           1              1.0              52
# 43    49           1              1.0              53
# 41    50           1              1.0              54
# 45    51           1              1.0              55
# 20    52           2              2.0              57
# 2     53           4              4.0              61
# 0     54           5              5.0              66
# 1     55           5              5.0              71
# 7     56           3              3.0              74
# 39    57           1              1.0              75
# 31    58           1              1.0              76
# 27    59           2              2.0              78
# 46    60           1              1.0              79
# 23    61           2              2.0              81
# 15    62           3              3.0              84
# 8     64           3              3.0              87
# 14    65           3              3.0              90
# 37    66           1              1.0              91
# 16    67           2              2.0              93
# 21    68           2              2.0              95
# 13    69           3              3.0              98
# 17    70           2              2.0             100

# %%
import math
import pandas as pd

print(edades)


df = pd.DataFrame({'edad' : edades})
df
# Out:
# [19, 67, 29, 62, 30, 46, 48, 31, 54, 59, 55, 53, 42, 40, 35, 46, 26, 27, 55, 54, 45, 33, 41, 64, 38, 44, 61, 34, 36, 51, 54, 35, 21, 34, 49, 32, 18, 62, 22, 61, 44, 50, 36, 43, 57, 56, 44, 55, 67, 26, 66, 27, 55, 23, 69, 70, 65, 47, 46, 52, 34, 56, 22, 58, 65, 36, 25, 53, 69, 36, 68, 32, 53, 34, 70, 33, 47, 64, 22, 62, 64, 54, 45, 60, 26, 55, 27, 65, 53, 26, 54, 46, 35, 38, 19, 68, 56, 69, 59, 52]
#     edad
# 0     19
# 1     67
# 2     29
# 3     62
# 4     30
# ..   ...
# 95    68
# 96    56
# 97    69
# 98    59
# 99    52
#
# [100 rows x 1 columns]

# %%
n = len(edades)
k = int(1 + math.log2(n))
print("valor de n =", n , " \nNumero de intervalos =", k)
# Out:
# valor de n = 100
# Numero de intervalos = 7

# %%
tabla_frecuencia = pd.cut(df['edad'], bins=k, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns = [ 'clase' , 'Frec']
tabla_frecuencia
# Out:
#               clase  Frec
# 0  (47.714, 55.143]    20
# 1  (32.857, 40.286]    16
# 2    (62.571, 70.0]    16
# 3  (40.286, 47.714]    14
# 4  (55.143, 62.571]    13
# 5  (25.429, 32.857]    12
# 6  (17.947, 25.429]     9

# %%
tabla_frecuencia = tabla_frecuencia.sort_values(by='clase')
tabla_frecuencia
# Out:
#               clase  Frec
# 6  (17.947, 25.429]     9
# 5  (25.429, 32.857]    12
# 1  (32.857, 40.286]    16
# 3  (40.286, 47.714]    14
# 0  (47.714, 55.143]    20
# 4  (55.143, 62.571]    13
# 2    (62.571, 70.0]    16

# %%
tabla_frecuencia['Frec Re1'] = tabla_frecuencia['Frec'] / n
tabla_frecuencia['Frec porc'] = tabla_frecuencia['Frec'] / n * 100
tabla_frecuencia['Frec Ac'] = tabla_frecuencia['Frec'].cumsum()
tabla_frecuencia['Frec Re1 Ac'] = tabla_frecuencia['Frec Re1'].cumsum()
tabla_frecuencia['Frec porc Ac'] = tabla_frecuencia['Frec porc'].cumsum()

print(tabla_frecuencia)
# Out:
#               clase  Frec  Frec Re1  Frec porc  Frec Ac  Frec Re1 Ac  \
# 6  (17.947, 25.429]     9      0.09        9.0        9         0.09
# 5  (25.429, 32.857]    12      0.12       12.0       21         0.21
# 1  (32.857, 40.286]    16      0.16       16.0       37         0.37
# 3  (40.286, 47.714]    14      0.14       14.0       51         0.51
# 0  (47.714, 55.143]    20      0.20       20.0       71         0.71
# 4  (55.143, 62.571]    13      0.13       13.0       84         0.84
# 2    (62.571, 70.0]    16      0.16       16.0      100         1.00
#
#    Frec porc Ac
# 6           9.0
# 5          21.0
# 1          37.0
# 3          51.0
# 0          71.0
# 4          84.0
# 2         100.0

# %%
import matplotlib.pyplot as plt
plt.hist(edades, alpha = 0.5, bins = 20)
plt.title("histograma de edades basado en la funicon de matplotlib con valores estandar")
# Out:
# Text(0.5, 1.0, 'histograma de edades basado en la funicon de matplotlib con valores estandar')

# %%
plt.hist(df['edad'], bins =k, alpha = 0.5)
plt.title('histograma de edades basado en la regla de sturges')
plt.xlabel('edades')
plt.ylabel('frecuencia')
# Out:
# Text(0, 0.5, 'frecuencia')

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ##PRACTICA 5
# #diagramas de cajas y bigotes
# Facilitador:DR Jose Gabriel Rodriguez Rivas
#
# Alumno:Luis David Enriquez Arevalo

# %%
import random
edades2 = []
for i in range (100):
    numero_aleatorio = random.randint(20,87)
    edades2.append(numero_aleatorio)
print(edades2)



fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(9,4))
bplot1= ax1.boxplot(edades,
                    vert=True,
                    patch_artist=True)
ax1.set_title('edades encuesta 1')



bplot2= ax2.boxplot(edades2,
                    vert=True,
                    patch_artist=True)
ax2.set_title('edades encuesta 2')
plt.show()
# Out:
# [39, 67, 53, 60, 56, 33, 37, 43, 24, 22, 30, 75, 35, 74, 60, 35, 70, 64, 85, 57, 55, 84, 33, 20, 74, 75, 57, 52, 28, 75, 65, 70, 44, 34, 59, 23, 37, 26, 27, 67, 60, 40, 30, 40, 83, 35, 27, 34, 37, 63, 39, 63, 51, 24, 60, 64, 25, 83, 56, 45, 63, 78, 37, 41, 31, 48, 67, 72, 36, 77, 54, 69, 35, 79, 39, 23, 52, 20, 25, 52, 64, 64, 50, 37, 69, 41, 35, 22, 55, 76, 21, 62, 32, 64, 25, 37, 78, 25, 37, 29]

# %%
edades2.append(130)
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(9,4))
bplot1= ax1.boxplot(edades,
                    vert=True,
                    patch_artist=True)
ax1.set_title('edades encuesta 1')



bplot2= ax2.boxplot(edades2,
                    vert=True,
                    patch_artist=True)
ax2.set_title('edades encuesta 2')
plt.show()
